# %%
import numpy as np
from sklearn.linear_model import LinearRegression

# %%
# 1. Input data (Hours studied)
X = np.array([1,2,3,4,5,6,7,8]).reshape(-1,1)

# %%
# 2. Output data (Marks)
y = np.array([35,40,50,55,65,70,80,85])

# %%
# 3. Create the model
model = LinearRegression()

# %%
# 4. Train the model
model.fit(X, y)
# Out:
# LinearRegression()

# %%
# 5. Ask the model to predict
prediction = model.predict([[10]])

# %%
print("Predicted marks for 7 hours study:", prediction[0])
# Out:
# Predicted marks for 7 hours study: 100.5952380952381

# %%
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# Data
X = np.array([1,2,3,4,5,6,7,8]).reshape(-1,1)
y = np.array([35,40,50,55,65,70,80,85])

# 1. Split data into training and testing
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25)

# 2. Create model
model = LinearRegression()

# 3. Train only on training data
model.fit(X_train, y_train)

# 4. Predict on test data (unseen data)
y_pred = model.predict(X_test)

print("Test inputs:", X_test.flatten())
print("Actual marks:", y_test)
print("Predicted marks:", y_pred)
print("Model score:", model.score(X_test, y_test))
# Out:
# Test inputs: [8 4]
# Actual marks: [85 55]
# Predicted marks: [86.66666667 56.66666667]
# Model score: 0.9876543209876543

# %%
import matplotlib.pyplot as plt

# Plot training data
plt.scatter(X_train, y_train)

# Plot the learned line
plt.plot(X_train, model.predict(X_train))

plt.xlabel("Hours studied")
plt.ylabel("Marks")
plt.title("Linear Regression Line")

plt.show()
